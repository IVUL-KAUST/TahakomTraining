# %% [markdown]
# # Tahakom Training Week 3: Beyond-supervised-training
# ##  Day1: Self-Supervised Learning: Rotation Prediction
#
# Today, we will explore the concepts of self-supervised learning using Rotation Prediction task.  During this practical session we will set up the development environment, implement its framework, pretraining and evaluation.

# %% [markdown]
# # Task Description: Rotation Prediction
# ## Background
# Self-Supervised Learning (SSL) is a technique that leverages the inherent structure in data to learn useful representations without the need for large amounts of labeled data. In computer vision tasks, SSL uses pretext tasks to train models, enabling them to extract meaningful information from unlabeled data. This approach is particularly valuable in visual tasks as it improves the model’s generalization ability for downstream tasks.
# Rotation prediction is a widely used pretext task in SSL, first introduced by Gidaris et al. in 2018. The core idea behind this task is to take an image, apply random rotations (e.g., 0°, 90°, 180°, and 270°), and require the model to predict the rotation angle. This forces the model to learn the semantic information and geometric structure of the objects in the image, resulting in more effective visual feature learning.
# Framework of [Rotation Prediction](https://arxiv.org/abs/1803.07728) is visualized below.
#
# <center width="100%"><img src="./rotnet.png" width="500px"></center>
#
#
# ## Task Definition
# In this assignment, we will use the rotation prediction task as a pre-training objective in a self-supervised learning framework. Specifically, we will apply four possible rotation transformations to the input images:
#
# 0°: No rotation, the image remains unchanged.
#
# 90°: Rotate the image 90 degrees clockwise.
#
# 180°: Rotate the image 180 degrees clockwise.
#
# 270°: Rotate the image 270 degrees clockwise.
#
# The goal is to design a model that takes in the rotated image and predicts the corresponding rotation angle class (0, 90, 180, or 270).

# %% [markdown]
# ## Data Setup
#
# The first thing to do is implement a dataset class to load rotated CIFAR10 images with matching labels. Since there is already a CIFAR10 dataset class implemented in `torchvision`, we will extend this class and modify the `__get_item__` method appropriately to load rotated images.
#
# Each rotation label should be an integer in the set {0, 1, 2, 3} which correspond to rotations of 0, 90, 180, or 270 degrees respectively.

# %%
import matplotlib.pyplot as plt
import numpy as np
from torchvision import datasets, transforms
import torch

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 170498071/170498071 [00:11<00:00, 14658541.75it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Visualization
# Show some example images with labels:

# %%
class Denormalize(object):
    def __init__(self, mean, std):
        self.mean = torch.tensor(mean).view(3, 1, 1)
        self.std = torch.tensor(std).view(3, 1, 1)

    def __call__(self, tensor):
        return tensor * self.std + self.mean

mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)

denormalize = Denormalize(mean, std)

# %%
num_images = 5
images, labels = zip(*[(test_dataset[i][0], test_dataset[i][1]) for i in range(num_images)])

def show_tensor_images(images, labels, classes):
    fig, axes = plt.subplots(1, len(images), figsize=(12, 3))
    for i, image in enumerate(images):
        image = denormalize(image)
        image = image.permute(1, 2, 0).numpy()  
        image = np.clip(image * 255, 0, 255).astype(np.uint8)
        axes[i].imshow(image)
        axes[i].set_title(classes[labels[i]])
        axes[i].axis('off')
    plt.show()

show_tensor_images(images, labels, test_dataset.classes)

# %% [markdown]
# ## Data Loading
# For this task, the CIFAR-100 dataset will be loaded and prepared using deep learning frameworks such as PyTorch. The images will be normalized, and during preprocessing, we will apply rotations of 0°, 90°, 180°, and 270° to create the data required for the rotation prediction task.

# %%
import torch

def rotate_image(image, rotation):
    if rotation == 90:
        return torch.rot90(image, 1, [1, 2])
    elif rotation == 180:
        return torch.rot90(image, 2, [1, 2])
    elif rotation == 270:
        return torch.rot90(image, 3, [1, 2])
    else:
        return image

# %%
import random

class RotationPredictionDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, seed=None):
        self.dataset = dataset
        self.rotations = [0, 90, 180, 270]
        self.labels = {0: 0, 90: 1, 180: 2, 270: 3}
        if seed is not None:
            random.seed(seed) 

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, _ = self.dataset[idx]

        rotation = random.choice(self.rotations)
        
        rotated_image = rotate_image(image, rotation)
        
        rotation_label = self.labels[rotation]

        return rotated_image, rotation_label

# %% [markdown]
# ## Visualization
# Show some rotated images with labels:

# %%
def visualize_rotation_dataset(dataset, num_images=5):
    images, labels = zip(*[dataset[i] for i in range(num_images)])

    fig, axes = plt.subplots(1, num_images, figsize=(12, 3))
    for i, image in enumerate(images):
        image = denormalize(image)
        image = image.permute(1, 2, 0).numpy()  
        image = np.clip(image * 255, 0, 255).astype(np.uint8)  
        axes[i].imshow(image)
        axes[i].set_title(f"Rotation: {labels[i] * 90}°")  
        axes[i].axis('off')
    plt.show()

# %%
pretrain_dataset = RotationPredictionDataset(train_dataset)
visualize_rotation_dataset(pretrain_dataset)
pretrain_test_dataset = RotationPredictionDataset(test_dataset)

# %% [markdown]
# ## Train a ResNet18 on the rotation task
#
# In this section, we will train a ResNet18 model on the rotation task. The input is a rotated image and the model predicts the rotation label. See the Data Setup section for details.

# %% [markdown]
# ### Sanity check

# %%
def sanity_check(model):
    B = 4
    input_tensor = torch.randn(B, 3, 32, 32)

    output = model(input_tensor)
    print(output.shape)

    return output

# %% [markdown]
# We will directly load `resnet18` from `torchvision.models`

# %%
from torchvision.models import resnet18

model = resnet18(num_classes=4)
sanity_check(model)
# Out:
# torch.Size([4, 4])
# tensor([[-0.1857, -0.7188,  1.5468,  0.8168],
#         [-0.2891,  1.1719,  1.1120,  0.2153],
#         [-0.5445, -0.2892,  0.3357, -0.8825],
#         [-0.4736,  0.2249,  0.9319, -0.0133]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Training code

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

def eval(model, model_path, dataset, batch_size, device):
    model.load_state_dict(torch.load(model_path))
    model.eval()

    test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    correct = 0
    total = 0

    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy:.2f}%')

def adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs=30):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = init_lr * (0.1 ** (epoch // decay_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


def train_model(model, train_loader, loss_fn, optimizer, epochs, save_path, device, init_lr, decay_epochs):
    model.train()  
    best_loss = float('inf')
    epoch_losses = []  
    
    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs)
            inputs, targets = inputs.to(device), targets.to(device)

            optimizer.zero_grad()

            outputs = model(inputs)
            loss = loss_fn(outputs, targets)
            
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        epoch_losses.append(avg_loss)  
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}')

        if avg_loss < best_loss:
            best_loss = avg_loss
            torch.save(model.state_dict(), save_path)
            print(f'Model is saved to {save_path}, Best Loss: {best_loss:.4f}')

    print("Training finished!")
    return epoch_losses

def plot_loss_curve(losses):
    plt.figure()
    plt.plot(range(1, len(losses) + 1), losses, marker='o')
    plt.title("Training Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Pretraining
# In this section, we will randomly initialize a ResNet18 model and pretrain on the rotation prediction task.

# %%
model = resnet18(num_classes=4)
batch_size = 128
epochs = 100
learning_rate = 0.01
decay_epochs = 15
best_save_path = "./best_pretrained_model.pth"
last_save_path = "./last_pretrained_model.pth"

train_loader = DataLoader(pretrain_dataset, batch_size=batch_size, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epoch_losses = train_model(model, train_loader, loss_fn, optimizer, epochs, best_save_path, device, init_lr=learning_rate, decay_epochs=decay_epochs)
plot_loss_curve(epoch_losses)
torch.save(model.state_dict(), last_save_path)

eval(model, last_save_path, pretrain_dataset, batch_size, device)
# Out:
# Epoch [1/100], Loss: 1.2912
# Model is saved to ./best_pretrained_model.pth, Best Loss: 1.2912
# Epoch [2/100], Loss: 1.0980
# Model is saved to ./best_pretrained_model.pth, Best Loss: 1.0980
# Epoch [3/100], Loss: 1.0382
# Model is saved to ./best_pretrained_model.pth, Best Loss: 1.0382
# Epoch [4/100], Loss: 0.9970
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.9970
# Epoch [5/100], Loss: 0.9529
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.9529
# Epoch [6/100], Loss: 0.9219
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.9219
# Epoch [7/100], Loss: 0.8903
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.8903
# Epoch [8/100], Loss: 0.8747
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.8747
# Epoch [9/100], Loss: 0.8499
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.8499
# Epoch [10/100], Loss: 0.8280
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.8280
# Epoch [11/100], Loss: 0.8140
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.8140
# Epoch [12/100], Loss: 0.7974
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.7974
# Epoch [13/100], Loss: 0.7780
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.7780
# Epoch [14/100], Loss: 0.7608
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.7608
# Epoch [15/100], Loss: 0.7493
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.7493
# Epoch [16/100], Loss: 0.6826
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6826
# Epoch [17/100], Loss: 0.6601
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6601
# Epoch [18/100], Loss: 0.6482
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6482
# Epoch [19/100], Loss: 0.6380
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6380
# Epoch [20/100], Loss: 0.6334
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6334
# Epoch [21/100], Loss: 0.6278
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6278
# Epoch [22/100], Loss: 0.6216
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6216
# Epoch [23/100], Loss: 0.6144
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6144
# Epoch [24/100], Loss: 0.6102
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6102
# Epoch [25/100], Loss: 0.6072
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6072
# Epoch [26/100], Loss: 0.6011
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.6011
# Epoch [27/100], Loss: 0.5965
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5965
# Epoch [28/100], Loss: 0.5947
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5947
# Epoch [29/100], Loss: 0.5903
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5903
# Epoch [30/100], Loss: 0.5867
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5867
# Epoch [31/100], Loss: 0.5735
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5735
# Epoch [32/100], Loss: 0.5725
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5725
# Epoch [33/100], Loss: 0.5712
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5712
# Epoch [34/100], Loss: 0.5674
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5674
# Epoch [35/100], Loss: 0.5666
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5666
# Epoch [36/100], Loss: 0.5698
# Epoch [37/100], Loss: 0.5665
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5665
# Epoch [38/100], Loss: 0.5681
# Epoch [39/100], Loss: 0.5682
# Epoch [40/100], Loss: 0.5662
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5662
# Epoch [41/100], Loss: 0.5665
# Epoch [42/100], Loss: 0.5644
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5644
# Epoch [43/100], Loss: 0.5630
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5630
# Epoch [44/100], Loss: 0.5631
# Epoch [45/100], Loss: 0.5603
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5603
# Epoch [46/100], Loss: 0.5608
# Epoch [47/100], Loss: 0.5623
# Epoch [48/100], Loss: 0.5604
# Epoch [49/100], Loss: 0.5639
# Epoch [50/100], Loss: 0.5629
# Epoch [51/100], Loss: 0.5639
# Epoch [52/100], Loss: 0.5592
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5592
# Epoch [53/100], Loss: 0.5636
# Epoch [54/100], Loss: 0.5601
# Epoch [55/100], Loss: 0.5598
# Epoch [56/100], Loss: 0.5599
# Epoch [57/100], Loss: 0.5593
# Epoch [58/100], Loss: 0.5627
# Epoch [59/100], Loss: 0.5612
# Epoch [60/100], Loss: 0.5595
# Epoch [61/100], Loss: 0.5583
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5583
# Epoch [62/100], Loss: 0.5631
# Epoch [63/100], Loss: 0.5617
# Epoch [64/100], Loss: 0.5596
# Epoch [65/100], Loss: 0.5582
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5582
# Epoch [66/100], Loss: 0.5606
# Epoch [67/100], Loss: 0.5622
# Epoch [68/100], Loss: 0.5598
# Epoch [69/100], Loss: 0.5604
# Epoch [70/100], Loss: 0.5605
# Epoch [71/100], Loss: 0.5614
# Epoch [72/100], Loss: 0.5611
# Epoch [73/100], Loss: 0.5633
# Epoch [74/100], Loss: 0.5588
# Epoch [75/100], Loss: 0.5628
# Epoch [76/100], Loss: 0.5641
# Epoch [77/100], Loss: 0.5586
# Epoch [78/100], Loss: 0.5600
# Epoch [79/100], Loss: 0.5604
# Epoch [80/100], Loss: 0.5617
# Epoch [81/100], Loss: 0.5620
# Epoch [82/100], Loss: 0.5571
# Model is saved to ./best_pretrained_model.pth, Best Loss: 0.5571
# Epoch [83/100], Loss: 0.5611
# Epoch [84/100], Loss: 0.5600
# Epoch [85/100], Loss: 0.5591
# Epoch [86/100], Loss: 0.5584
# Epoch [87/100], Loss: 0.5593
# Epoch [88/100], Loss: 0.5599
# Epoch [89/100], Loss: 0.5596
# Epoch [90/100], Loss: 0.5588
# Epoch [91/100], Loss: 0.5598
# Epoch [92/100], Loss: 0.5621
# Epoch [93/100], Loss: 0.5630
# Epoch [94/100], Loss: 0.5589
# Epoch [95/100], Loss: 0.5616
# Epoch [96/100], Loss: 0.5603
# Epoch [97/100], Loss: 0.5613
# Epoch [98/100], Loss: 0.5620
# Epoch [99/100], Loss: 0.5591
# Epoch [100/100], Loss: 0.5604
# Training finished!
# Test Accuracy: 78.50%

# %% [markdown]
# ## Supervised training
# In this section, we will randomly initialize a ResNet18 model and fine-tune on the classification task.

# %%
model = resnet18(num_classes=10)
batch_size = 128
epochs = 20
learning_rate = 0.01
decay_epochs = 10
best_save_path = "./best_supervised_pretrained_model.pth"
last_save_path = "./last_supervised_pretrained_model.pth"

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epoch_losses = train_model(model, train_loader, loss_fn, optimizer, epochs, best_save_path, device, init_lr=learning_rate, decay_epochs=decay_epochs)
plot_loss_curve(epoch_losses)
torch.save(model.state_dict(), last_save_path)
eval(model, last_save_path, test_dataset, batch_size, device)

# %% [markdown]
# ## Finetuning
# In this section, we will load the pretrained weight and fine-tune on the classification task.

# %%
model = resnet18(num_classes=10)
state_dict = torch.load('last_pretrained_model.pth')
new_state_dict = {k: v for (k, v) in state_dict.items() if 'fc' not in k}

missing_keys, unexpected_keys = model.load_state_dict(new_state_dict, strict=False)

print("missing keys", missing_keys)
print("unexpected_keys:", unexpected_keys)
# Out:
# missing keys ['fc.weight', 'fc.bias']
# unexpected_keys: []

# %%
batch_size = 128
epochs = 20
learning_rate = 0.01
decay_epochs = 10
best_save_path = "./best_finetune_pretrained_model.pth"
last_save_path = "./last_finetune_pretrained_model.pth"

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epoch_losses = train_model(model, train_loader, loss_fn, optimizer, epochs, best_save_path, device, learning_rate, decay_epochs=decay_epochs)
plot_loss_curve(epoch_losses)
torch.save(model.state_dict(), last_save_path)
eval(model, last_save_path, test_dataset, batch_size, device)
# Out:
# Epoch [1/20], Loss: 1.2077
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 1.2077
# Epoch [2/20], Loss: 0.9254
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.9254
# Epoch [3/20], Loss: 0.8176
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.8176
# Epoch [4/20], Loss: 0.7552
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.7552
# Epoch [5/20], Loss: 0.7002
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.7002
# Epoch [6/20], Loss: 0.6598
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.6598
# Epoch [7/20], Loss: 0.6263
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.6263
# Epoch [8/20], Loss: 0.5982
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.5982
# Epoch [9/20], Loss: 0.5730
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.5730
# Epoch [10/20], Loss: 0.5444
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.5444
# Epoch [11/20], Loss: 0.4562
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.4562
# Epoch [12/20], Loss: 0.4195
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.4195
# Epoch [13/20], Loss: 0.4101
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.4101
# Epoch [14/20], Loss: 0.3920
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3920
# Epoch [15/20], Loss: 0.3904
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3904
# Epoch [16/20], Loss: 0.3806
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3806
# Epoch [17/20], Loss: 0.3684
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3684
# Epoch [18/20], Loss: 0.3666
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3666
# Epoch [19/20], Loss: 0.3607
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3607
# Epoch [20/20], Loss: 0.3543
# Model is saved to ./best_finetune_pretrained_model.pth, Best Loss: 0.3543
# Training finished!
# Test Accuracy: 83.45%

# %% [markdown]
# ## Linear evaluation
# In this section, we will load the pretrained weight and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.

# %%
model = resnet18(num_classes=10)
state_dict = torch.load('last_pretrained_model.pth')
new_state_dict = {k: v for (k, v) in state_dict.items() if 'fc' not in k}

missing_keys, unexpected_keys = model.load_state_dict(new_state_dict, strict=False)

print("missing keys", missing_keys)
print("unexpected_keys:", unexpected_keys)

for name, param in model.named_parameters():
    if not name.startswith('layer4') and not name.startswith('fc'):
        param.requires_grad = False
# Out:
# missing keys ['fc.weight', 'fc.bias']
# unexpected_keys: []

# %%
batch_size = 128
epochs = 20
learning_rate = 0.01
decay_epochs = 10
best_save_path = "./best_linear_pretrained_model.pth"
last_save_path = "./last_linear_pretrained_model.pth"

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epoch_losses = train_model(model, train_loader, loss_fn, optimizer, epochs, best_save_path, device, learning_rate, decay_epochs=decay_epochs)
plot_loss_curve(epoch_losses)
torch.save(model.state_dict(), last_save_path)
eval(model, last_save_path, test_dataset, batch_size, device)
# Out:
# Epoch [1/20], Loss: 1.5369
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.5369
# Epoch [2/20], Loss: 1.3762
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.3762
# Epoch [3/20], Loss: 1.3254
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.3254
# Epoch [4/20], Loss: 1.2958
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2958
# Epoch [5/20], Loss: 1.2776
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2776
# Epoch [6/20], Loss: 1.2604
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2604
# Epoch [7/20], Loss: 1.2517
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2517
# Epoch [8/20], Loss: 1.2375
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2375
# Epoch [9/20], Loss: 1.2253
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2253
# Epoch [10/20], Loss: 1.2212
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.2212
# Epoch [11/20], Loss: 1.1661
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1661
# Epoch [12/20], Loss: 1.1486
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1486
# Epoch [13/20], Loss: 1.1403
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1403
# Epoch [14/20], Loss: 1.1333
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1333
# Epoch [15/20], Loss: 1.1274
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1274
# Epoch [16/20], Loss: 1.1243
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1243
# Epoch [17/20], Loss: 1.1211
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1211
# Epoch [18/20], Loss: 1.1196
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1196
# Epoch [19/20], Loss: 1.1098
# Model is saved to ./best_linear_pretrained_model.pth, Best Loss: 1.1098
# Epoch [20/20], Loss: 1.1118
# Training finished!
# Test Accuracy: 60.47%
